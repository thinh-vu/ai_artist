# %% [markdown]
# <a href="https://colab.research.google.com/github/thinh-vu/ai_artist/blob/main/vnstock_demo_api_du_lieu_chung_khoan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color=red>Đọc thêm hướng dẫn đầy đủ tại trang thông tin chính thức của vnstock trên Github [tại đây](https://github.com/thinh-vu/vnstock)</font>

# %% [markdown]
# # I. Thiết lập

# %%
pip install vnstock # cài đặt thư viện vào Google Colab, cần chạy lại nếu dùng hosted runtime engine của Google
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from vnstock import * # nhập các hàm viết sẵn của thư viện vào workbook

# %% [markdown]
# # II. Demo truy xuất dữ liệu

# %% [markdown]
# ## Liệt kê danh sách các mã cổ phiếu trên thị trường

# %%
listing_companies()
# Out:
#      ticker  group_code                                       company_name  \
# 0       HSV  UpcomIndex                   Công ty Cổ phần Gang Thép Hà Nội
# 1       SCV  UpcomIndex                      Công ty Cổ phần Muối Việt Nam
# 2       LYF  UpcomIndex               Công ty Cổ phần Lương Thực Lương Yên
# 3       CST  UpcomIndex                 Công ty Cổ phần Than Cao Sơn - TKV
# 4       BVL  UpcomIndex                            Công ty Cổ phần BV Land
# ...     ...         ...                                                ...
# 1621    XMP  UpcomIndex                Công ty Cổ phần Thủy điện Xuân Minh
# 1622    YBC  UpcomIndex      Công ty Cổ phần Xi măng và Khoáng sản Yên Bái
# 1623    YBM     VNINDEX     Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái
# 1624    YEG     VNINDEX                     Công ty Cổ phần Tập đoàn Yeah1
# 1625    YTC  UpcomIndex  Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...
#
#                  company_short_name
# ...

# %% [markdown]
# ## Tóm tắt thông tin cơ bản của 1 mã cổ phiếu bất kỳ

# %%
ticker_overview('TCB') #tóm tắt thông tin cổ phiếu TCB, thay thế mã cổ phiếu bạn cần tra cứu và chạy lệnh, sử dụng vòng lặp để lấy kết quả cho nhiều mã cổ phiếu nếu cần
# Out:
#   exchange    shortName  industryID industryIDv2   industry industryEn  \
# 0     HOSE  Techcombank         289         8355  Ngân hàng      Banks
#
#   establishedYear  noEmployees  noShareholders  foreignPercent  \
# 0            1993         9757            1901           0.225
#
#                          website  stockRating  deltaInWeek  deltaInMonth  \
# 0  http://www.techcombank.com.vn          2.8       -0.031        -0.071
#
#    deltaInYear  outstandingShare  issueShare companyType ticker
# 0       -0.221            3517.2      3510.9          NH    TCB

# %% [markdown]
# ## Truy cứu dữ liệu lịch sử giá của 1 mã cổ phiếu bất kỳ

# %%
df =  stock_historical_data(symbol='GMD', start_date="2021-01-01", end_date='2022-09-22')

# %%
df
# Out:
#         Open     High      Low    Close   Volume TradingDate
# 0    32182.0  33157.0  31987.0  32279.0  4226500  2021-01-04
# 1    32279.0  33596.0  31938.0  32962.0  4851900  2021-01-05
# 2    33352.0  33352.0  32279.0  32572.0  3641300  2021-01-06
# 3    32864.0  33644.0  31694.0  33157.0  5753700  2021-01-07
# 4    33547.0  33937.0  32669.0  33059.0  4587500  2021-01-08
# ..       ...      ...      ...      ...      ...         ...
# 424  48850.0  49000.0  46800.0  47000.0  1317200  2022-09-19
# 425  47750.0  48000.0  47050.0  48000.0   697300  2022-09-20
# 426  47300.0  48200.0  47300.0  47950.0   669800  2022-09-21
# 427  47500.0  49150.0  47500.0  49000.0   512800  2022-09-22
# 428  47500.0  49150.0  47500.0  49000.0   512800  2022-09-22
#
# [429 rows x 6 columns]

# %% [markdown]
# ## So sánh thông tin giao dịch của 1 danh sách các mã cổ phiếu cần tra cứu

# %%
price_board('TCB,SSI,VND')
# Out:
#   Mã CP  Giá Khớp Lệnh  KLBD/TB5D  T.độ GD  KLGD ròng(CM)  %KLGD ròng (CM)  \
# 0   TCB        34550.0       1.26     2.23          30000              9.0
# 1   SSI        21100.0       1.16     2.30         310100             11.8
# 2   VND        19000.0       1.12     2.15          97000              4.3
#
#          RSI  MACD Volume MACD Signal Tín hiệu KT  ... Khối lượng Dư mua  \
# 0  21.436995        -0.41     Neutral     Neutral  ...             38600
# 1  39.166361        -0.26     Neutral         Buy  ...            245800
# 2  39.407316        -0.25     Neutral     Neutral  ...            254700
#
#    Khối lượng Dư bán  Khớp nhiều nhất         seq  vnid3d  vnid1m  vnid3m  \
# 0              11800            34200  1663833540     0.4    -4.6     2.6
# 1             695700            20600  1663833540     0.4    -4.6     2.6
# 2             364000            19000  1663833540     0.4    -4.6     2.6
#
#    vnid1y    vnipe    vnipb
# 0   -10.4  13.2673  1.90595
# ...

# %% [markdown]
# ## Dữ liệu intraday thể hiện thông tin giao dịch theo thời gian trong ngày

# %%
stock_intraday_data(symbol='GMD', page_num=0, page_size=5000)
# Out:
#        price  volume      cp  rcp   a        ba        sa     hl    pcp  \
# 0    49000.0   15900  1050.0  0.0      370400.0  158900.0  False    0.0
# 1    49000.0     100  1050.0  0.0  BU  370400.0  158900.0  False    0.0
# 2    49000.0     100  1050.0  0.0  SD  370300.0  158900.0  False -100.0
# 3    49100.0    1500  1150.0  0.0  BU  370300.0  158800.0  False    0.0
# 4    49100.0     500  1150.0  0.0  SD  368800.0  156800.0  False    0.0
# ..       ...     ...     ...  ...  ..       ...       ...    ...    ...
# 607  47500.0     100  -450.0  0.0  SD    5300.0    7800.0  False    0.0
# 608  47500.0     200  -450.0  0.0  BU    5300.0    7700.0  False    0.0
# 609  47500.0    4200  -450.0  0.0  BU    4300.0    7700.0  False    0.0
# 610  47500.0     800  -450.0  0.0  BU    5100.0    7700.0  False    0.0
# 611  47500.0     100  -450.0  0.0  BU     100.0    7700.0  False -450.0
#
#          time
# 0    14:45:02
# 1    14:28:32
# 2    14:27:53
# 3    14:27:50
# 4    14:27:13
# ...

# %% [markdown]
# # II. Xuất dữ liệu

# %% [markdown]
# Chạy từng dòng lệnh hoặc thu gọn mục II này lại và chạy toàn bộ lệnh trong mục này

# %%
from google.colab import drive # kết nối Google Drive với Colab notebook, cần cho phép kết nối khi pop up mở ra
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# Demo cách truy xuất dữ liệu và lưu file hoàn chỉnh

# %%
df =  stock_historical_data(symbol='GMD', start_date="2021-01-01", end_date='2022-09-22') # truy xuất lịch sử giá của cổ phiếu GMD
df.head()
# Out:
#       Open     High      Low    Close   Volume TradingDate
# 0  32182.0  33157.0  31987.0  32279.0  4226500  2021-01-04
# 1  32279.0  33596.0  31938.0  32962.0  4851900  2021-01-05
# 2  33352.0  33352.0  32279.0  32572.0  3641300  2021-01-06
# 3  32864.0  33644.0  31694.0  33157.0  5753700  2021-01-07
# 4  33547.0  33937.0  32669.0  33059.0  4587500  2021-01-08

# %%
df.to_csv('/content/drive/MyDrive/ten_file_cua_ban.csv', index=False) # Lưu file dưới dạng csv vào thư mục gốc của Google Drive

# %%
# df.to_excel('/content/drive/MyDrive/ten_file_cua_ban.xlsx', index=False) # xoá dấu thăng ở đầu dòng này nếu muốn chạy lệnh lưu file thành định dạng excel
